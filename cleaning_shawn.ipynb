# %%
import pandas as pd
df = pd.DataFrame(pd.read_csv("final_merged"))
df.head()
# Out:
#    Unnamed: 0  Unnamed: 0_x color_x    director_name_x  \
# 0           0             0   Color      James Cameron
# 1           1             1   Color     Gore Verbinski
# 2           2             2   Color         Sam Mendes
# 3           3             3   Color  Christopher Nolan
# 4           4             5   Color     Andrew Stanton
#
#    num_critic_for_reviews_x  duration_x  director_facebook_likes_x  \
# 0                     723.0       178.0                        0.0
# 1                     302.0       169.0                      563.0
# 2                     602.0       148.0                        0.0
# 3                     813.0       164.0                    22000.0
# 4                     462.0       132.0                      475.0
#
#    actor_3_facebook_likes_x    actor_2_name_x  actor_1_facebook_likes_x  ...  \
# 0                     855.0  Joel David Moore                    1000.0  ...
# 1                    1000.0     Orlando Bloom                   40000.0  ...
# 2                     161.0      Rory Kinnear                   11000.0  ...
# 3                   23000.0    Christian Bale                   27000.0  ...
# 4                     530.0   Samantha Morton                     640.0  ...
#
#                                             overview runtime  \
# 0  In the 22nd century, a paraplegic Marine is di...     162
# 1  Captain Barbossa, long believed to be dead, ha...     169
# 2  A cryptic message from Bondâ€™s past sends him...     148
# 3  Following the death of District Attorney Harve...     165
# 4  Civil War vet John Carter is transplanted to M...     132
#
#                                      genres  \
# 0  Action|Adventure|Fantasy|Science Fiction
# 1                  Adventure|Fantasy|Action
# 2                    Action|Adventure|Crime
# 3               Action|Crime|Drama|Thriller
# 4  Action|Adventure|Fantasy|Science Fiction
#
#                                 production_companies  release_date  \
# 0  Ingenious Film Partners|Twentieth Century Fox ...    12/10/2009
# 1  Walt Disney Pictures|Jerry Bruckheimer Films|S...     5/19/2007
# 2                       Columbia Pictures|Danjaq|B24    10/26/2015
# 3  Legendary Pictures|Warner Bros.|DC Entertainme...     7/16/2012
# 4                               Walt Disney Pictures      3/7/2012
#
#    vote_count vote_average  release_year   budget_adj   revenue_adj
# 0        8458          7.1          2009  240886902.9  2.827124e+09
# 1        2626          6.8          2007  315500574.8  1.010654e+09
# 2        3254          6.2          2015  225399900.8  8.102203e+08
# 3        6723          7.5          2012  237436070.3  1.026713e+09
# 4        1479          6.0          2012  246933513.2  2.698595e+08
#
# [5 rows x 80 columns]

# %%
df = df.drop(columns=[
    "Unnamed: 0",
    "Unnamed: 0_x",
    'Unnamed: 0_y',
    'color_y',
    'director_name_y',
    'num_critic_for_reviews_y',
    'duration_y',
    'director_facebook_likes_y',
    'actor_3_facebook_likes_y',
    'actor_2_name_y',
    'actor_1_facebook_likes_y',
    'actor_1_name_y',
    'num_voted_users_y',
    'cast_total_facebook_likes_y',
    'actor_3_name_y',
    'facenumber_in_poster_y',
    'plot_keywords_y',
    'movie_imdb_link_y',
    'num_user_for_reviews_y',
    'language_y',
    'country_y',
    'content_rating_y',
    'gross_y',
    'genres_y',
    'budget_y',
    'title_year_y',
    'actor_2_facebook_likes_y',
    'imdb_score_y',
    'aspect_ratio_y',
    'movie_facebook_likes_y',
    'imdb_id_y',
    'imdb_id',
    'budget',
    'director',
    'keywords',
    'genres',
    'title_year_x'
                     ])
df.head()
# Out:
#   color_x    director_name_x  num_critic_for_reviews_x  duration_x  \
# 0   Color      James Cameron                     723.0       178.0
# 1   Color     Gore Verbinski                     302.0       169.0
# 2   Color         Sam Mendes                     602.0       148.0
# 3   Color  Christopher Nolan                     813.0       164.0
# 4   Color     Andrew Stanton                     462.0       132.0
#
#    director_facebook_likes_x  actor_3_facebook_likes_x    actor_2_name_x  \
# 0                        0.0                     855.0  Joel David Moore
# 1                      563.0                    1000.0     Orlando Bloom
# 2                        0.0                     161.0      Rory Kinnear
# 3                    22000.0                   23000.0    Christian Bale
# 4                      475.0                     530.0   Samantha Morton
#
#    actor_1_facebook_likes_x      gross_x                         genres_x  \
# 0                    1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                   40000.0  309404152.0         Action|Adventure|Fantasy
# 2                   11000.0  200074175.0        Action|Adventure|Thriller
# 3                   27000.0  448130642.0                  Action|Thriller
# 4                     640.0   73058679.0          Action|Adventure|Sci-Fi
#
#    ...                                         tagline  \
# 0  ...                     Enter the World of Pandora.
# 1  ...  At the end of the world, the adventure begins.
# 2  ...                           A Plan No One Escapes
# 3  ...                                 The Legend Ends
# 4  ...            Lost in Our World. Found in Another.
#
#                                             overview  runtime  \
# 0  In the 22nd century, a paraplegic Marine is di...      162
# 1  Captain Barbossa, long believed to be dead, ha...      169
# 2  A cryptic message from Bondâ€™s past sends him...      148
# 3  Following the death of District Attorney Harve...      165
# 4  Civil War vet John Carter is transplanted to M...      132
#
#                                 production_companies release_date  vote_count  \
# 0  Ingenious Film Partners|Twentieth Century Fox ...   12/10/2009        8458
# 1  Walt Disney Pictures|Jerry Bruckheimer Films|S...    5/19/2007        2626
# 2                       Columbia Pictures|Danjaq|B24   10/26/2015        3254
# 3  Legendary Pictures|Warner Bros.|DC Entertainme...    7/16/2012        6723
# 4                               Walt Disney Pictures     3/7/2012        1479
#
#   vote_average release_year   budget_adj   revenue_adj
# 0          7.1         2009  240886902.9  2.827124e+09
# 1          6.8         2007  315500574.8  1.010654e+09
# 2          6.2         2015  225399900.8  8.102203e+08
# 3          7.5         2012  237436070.3  1.026713e+09
# 4          6.0         2012  246933513.2  2.698595e+08
#
# [5 rows x 43 columns]

# %%
df = df.rename(columns={
    'color_x': 'Colouring',
    'director_name_x': 'Director',
    'num_critic_for_reviews_x': 'Critic Review Count',
    'duration_x': 'Duration',
    'director_facebook_likes_x': 'Director Facebook Likes',
    'actor_3_facebook_likes_x': 'Actor 3 Facebook Likes',
    'actor_2_name_x': "Actor 2",
    'actor_1_facebook_likes_x': 'Actor 1 Facebook Likes',
    'gross_x': 'Gross',
    'genres_x': 'Genres',
    'actor_1_name_x': 'Actor 1',
    'title': 'Title',
    'num_voted_users_x': 'IMDb Votes',
    'cast_total_facebook_likes_x': 'Cast Facebook Likes',
    'actor_3_name_x': 'Actor 3',
    'facenumber_in_poster_x': 'Poster Facenumber',
    'plot_keywords_x': 'Plot Keywords',
    'movie_imdb_link_x': 'IMDb Link',
    'num_user_for_reviews_x': 'User Review Count',
    'language_x': 'Language',
    'country_x': 'Country',
    'content_rating_x': 'Countent Rating',
    'budget_x': 'Budget',
    'actor_2_facebook_likes_x': 'Actor 2 Facebook Likes',
    'imdb_score_x': 'IMDb Score',
    'aspect_ratio_x': 'Aspect Ratio',
    'movie_facebook_likes_x': 'Facebook Likes',
    'imdb_id_x': 'IMDb ID',
    'popularity': 'Popularity',
    'revenue': 'Revenue',
    'cast': 'Cast',
    'homepage': 'Homepage',
    'tagline': 'Tagline',
    'overview': 'Overview',
    'runtime': 'Runtime',
    'production_companies': 'Production Companies',
    'release_date': 'Release Date',
    'vote_count': 'Vote Count',
    'vote_average': 'Average Vote',
    'release_year': 'Release Year',
    'budget_adj': 'Adjusted Budget',
    'revenue_adj': 'Adjusted Revenue'
})

# %%
df['Title'] = [x.strip('??') for x in df['Title']]

# %%
df["Genres"] = df["Genres"].str.split(pat = "|", expand = True)
df
# Out:
#      Colouring           Director  Critic Review Count  Duration  \
# 0        Color      James Cameron                723.0     178.0
# 1        Color     Gore Verbinski                302.0     169.0
# 2        Color         Sam Mendes                602.0     148.0
# 3        Color  Christopher Nolan                813.0     164.0
# 4        Color     Andrew Stanton                462.0     132.0
# ...        ...                ...                  ...       ...
# 4297     Color      Alex Kendrick                  5.0     120.0
# 4298     Color        John Waters                 73.0     108.0
# 4299     Color   Kiyoshi Kurosawa                 78.0     111.0
# 4300     Color      Shane Carruth                143.0      77.0
# 4301     Color   Robert Rodriguez                 56.0      81.0
#
#       Director Facebook Likes  Actor 3 Facebook Likes           Actor 2  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# 2                         0.0                   161.0      Rory Kinnear
# 3                     22000.0                 23000.0    Christian Bale
# 4                       475.0                   530.0   Samantha Morton
# ...                       ...                     ...               ...
# 4297                    589.0                     4.0       Lisa Arnold
# 4298                      0.0                   105.0        Mink Stole
# 4299                     62.0                     6.0     Anna Nakagawa
# 4300                    291.0                     8.0    David Sullivan
# 4301                      0.0                     6.0   Peter Marquardt
#
#       Actor 1 Facebook Likes        Gross  Genres  ...  \
# 0                     1000.0  760505847.0  Action  ...
# 1                    40000.0  309404152.0  Action  ...
# 2                    11000.0  200074175.0  Action  ...
# 3                    27000.0  448130642.0  Action  ...
# 4                      640.0   73058679.0  Action  ...
# ...                      ...          ...     ...  ...
# 4297                    51.0          NaN   Drama  ...
# 4298                   462.0     180483.0  Comedy  ...
# 4299                    89.0      94596.0   Crime  ...
# 4300                   291.0     424760.0   Drama  ...
# 4301                   121.0    2040920.0  Action  ...
#
#                                                 Tagline  \
# 0                           Enter the World of Pandora.
# 1        At the end of the world, the adventure begins.
# 2                                 A Plan No One Escapes
# 3                                       The Legend Ends
# 4                  Lost in Our World. Found in Another.
# ...                                                 ...
# 4297                                                NaN
# 4298                         An exercise in poor taste.
# 4299          The best cure for a disease is friendship
# 4300                 What happens if it actually works?
# 4301  He didn't come looking for trouble, but troubl...
#
#                                                Overview  Runtime  \
# 0     In the 22nd century, a paraplegic Marine is di...      162
# 1     Captain Barbossa, long believed to be dead, ha...      169
# 2     A cryptic message from Bondâ€™s past sends him...      148
# 3     Following the death of District Attorney Harve...      165
# 4     Civil War vet John Carter is transplanted to M...      132
# ...                                                 ...      ...
# 4297  Jay Austin wants to sell you a used car, but w...      120
# 4298  Notorious Baltimore criminal and underground f...       93
# 4299  Dexter, age 11, who has AIDS, and his next doo...       97
# 4300  Friends/fledgling entrepreneurs invent a devic...       79
# 4301  El Mariachi just wants to play his guitar and ...       81
#
#                                    Production Companies Release Date  \
# 0     Ingenious Film Partners|Twentieth Century Fox ...   12/10/2009
# 1     Walt Disney Pictures|Jerry Bruckheimer Films|S...    5/19/2007
# 2                          Columbia Pictures|Danjaq|B24   10/26/2015
# 3     Legendary Pictures|Warner Bros.|DC Entertainme...    7/16/2012
# 4                                  Walt Disney Pictures     3/7/2012
# ...                                                 ...          ...
# 4297                                                NaN     1/1/2003
# 4298                              Dreamland Productions    3/12/1972
# 4299                    Universal Pictures|Island World    4/21/1995
# 4300                                          Thinkfilm    10/8/2004
# 4301                                  Columbia Pictures     9/4/1992
#
#       Vote Count Average Vote Release Year  Adjusted Budget Adjusted Revenue
# 0           8458          7.1         2009     2.408869e+08     2.827124e+09
# 1           2626          6.8         2007     3.155006e+08     1.010654e+09
# 2           3254          6.2         2015     2.253999e+08     8.102203e+08
# 3           6723          7.5         2012     2.374361e+08     1.026713e+09
# 4           1479          6.0         2012     2.469335e+08     2.698595e+08
# ...          ...          ...          ...              ...              ...
# 4297          13          6.9         2003     0.000000e+00     0.000000e+00
# 4298          51          6.3         1972     6.257473e+04     3.128737e+07
# 4299          30          7.1         1995     0.000000e+00     0.000000e+00
# 4300         341          6.9         2004     8.081118e+03     4.903622e+05
# 4301         116          6.5         1992     3.418853e+05     3.171639e+06
#
# [4302 rows x 43 columns]

# %%
df.to_csv("final_data.csv")
# Out:
# 0       Action
# 1       Action
# 2       Action
# 3       Action
# 4       Action
#          ...
# 4297     Drama
# 4298    Comedy
# 4299     Crime
# 4300     Drama
# 4301    Action
# Name: Genres, Length: 4302, dtype: object
